# %%
import numpy as np

# %%
import pandas as pd

# %%
pip install textdistance
# Out:
# Collecting textdistance
#   Downloading textdistance-4.2.1-py3-none-any.whl (28 kB)
# Installing collected packages: textdistance
# Successfully installed textdistance-4.2.1

# %%
import textdistance as td

# %%
castDf = pd.read_stata('cast.dta')
castDf.head()
# Out:
#               stateid  distid  psuid  ...  id12bnm_ihds2  id13_ihds2     _merge
# 0  Jammu & Kashmir 01       2      1  ...                      OBC 3       both
# 1  Jammu & Kashmir 01       2      1  ...                        NaN  only 2005
# 2  Jammu & Kashmir 01       2      1  ...                        NaN       both
# 3  Jammu & Kashmir 01       2      1  ...                      OBC 3       both
# 4  Jammu & Kashmir 01       2      1  ...                  Forward 2       both
#
# [5 rows x 18 columns]

# %%
castDf['id12anm_ihds2_upd'] = castDf['id12anm_ihds2'].copy()
castDf
# Out:
#                   stateid  distid  ...     _merge  id12anm_ihds2_upd
# 0      Jammu & Kashmir 01       2  ...       both
# 1      Jammu & Kashmir 01       2  ...  only 2005
# 2      Jammu & Kashmir 01       2  ...       both
# 3      Jammu & Kashmir 01       2  ...       both
# 4      Jammu & Kashmir 01       2  ...       both              MALIK
# ...                   ...     ...  ...        ...                ...
# 46950      Pondicherry 34       0  ...       both           VANNIYAR
# 46951      Pondicherry 34       0  ...       both           VANNIYAR
# 46952      Pondicherry 34       0  ...       both           VANNIYAR
# 46953      Pondicherry 34       0  ...       both           VANNIYAR
# 46954      Pondicherry 34       0  ...       both            VANNIAR
#
# [46955 rows x 19 columns]

# %%
castDf
# Out:
#                   stateid  distid  ...     _merge  id12anm_ihds2_upd
# 0      Jammu & Kashmir 01       2  ...       both
# 1      Jammu & Kashmir 01       2  ...  only 2005
# 2      Jammu & Kashmir 01       2  ...       both
# 3      Jammu & Kashmir 01       2  ...       both
# 4      Jammu & Kashmir 01       2  ...       both              MALIK
# ...                   ...     ...  ...        ...                ...
# 46950      Pondicherry 34       0  ...       both           VANNIYAR
# 46951      Pondicherry 34       0  ...       both           VANNIYAR
# 46952      Pondicherry 34       0  ...       both           VANNIYAR
# 46953      Pondicherry 34       0  ...       both           VANNIYAR
# 46954      Pondicherry 34       0  ...       both            VANNIAR
#
# [46955 rows x 19 columns]

# %%
castDf['id12anm_ihds2_upd'][4590]
# Out:
# 'ANUSUCHIT'

# %%
ptr = 0
castList = []
castList.append(castDf['id12anm_ihds2_upd'][0])
for i in range(1,len(castDf)):
    count = 0
    for j in range(len(castList)):
        if(td.sorensen.normalized_similarity(castDf['id12anm_ihds2_upd'][i].lower(),castList[j].lower())>0.75):
            castDf['id12anm_ihds2_upd'][i] = castList[j]
            count += 1
    if(count == 0):
        castList.append(castDf['id12anm_ihds2_upd'][i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-cabb89a7e37a> in <module>()
#       5     count = 0
#       6     for j in range(len(castList)):
# ----> 7         if(td.sorensen.normalized_similarity(castDf['id12anm_ihds2_upd'][i].lower(),castList[j].lower())>0.75):
#       8             castDf['id12anm_ihds2_upd'][i] = castList[j]
#       9             count += 1
#
# /usr/local/lib/python3.7/dist-packages/textdistance/algorithms/base.py in normalized_similarity(self, *sequences)
#      51         normalized_similarity = 1 - normalized_distance
#      52         """
# ---> 53         return 1 - self.normalized_distance(*sequences)
#      54
#      55     def external_answer(self, *sequences):
#
# /usr/local/lib/python3.7/dist-packages/textdistance/algorithms/base.py in normalized_distance(self, *sequences)
#      44         if maximum == 0:
#      45             return 0
# ---> 46         return self.distance(*sequences) / maximum
#      47
#      48     def normalized_similarity(self, *sequences):
#
# /usr/local/lib/python3.7/dist-packages/textdistance/algorithms/base.py in distance(self, *sequences)
#     170 class BaseSimilarity(Base):
#     171     def distance(self, *sequences):
# --> 172         return self.maximum(*sequences) - self.similarity(*sequences)
#     173
#     174     def similarity(self, *sequences):
#
# /usr/local/lib/python3.7/dist-packages/textdistance/algorithms/base.py in similarity(self, *sequences)
#     173
#     174     def similarity(self, *sequences):
# --> 175         return self(*sequences)
#     176
#     177     def quick_answer(self, *sequences):
#
# /usr/local/lib/python3.7/dist-packages/textdistance/algorithms/token_based.py in __call__(self, *sequences)
#      72             return result
#      73
# ---> 74         sequences = self._get_counters(*sequences)               # sets
#      75         count = sum(self._count_counters(s) for s in sequences)
#      76         intersection = self._intersect_counters(*sequences)      # set
#
# /usr/local/lib/python3.7/dist-packages/textdistance/algorithms/base.py in _get_counters(self, *sequences)
#     133         if all(isinstance(s, Counter) for s in sequences):
#     134             return sequences
# --> 135         return [Counter(s) for s in self._get_sequences(*sequences)]
#     136
#     137     def _intersect_counters(self, *sequences):
#
# /usr/local/lib/python3.7/dist-packages/textdistance/algorithms/base.py in <listcomp>(.0)
#     133         if all(isinstance(s, Counter) for s in sequences):
#     134             return sequences
# --> 135         return [Counter(s) for s in self._get_sequences(*sequences)]
#     136
#     137     def _intersect_counters(self, *sequences):
#
# KeyboardInterrupt:

# %%
a = "Vannier"
b = "vannyer"

print(td.sorensen.normalized_similarity(a.lower(),b.lower()))
# Out:
# 0.8571428571428571

# %%
listCastUnique = []
for i in range(5,400):
    if(castDf['id12anm_ihds2'][i] != ""):
        listCastUnique.append(castDf['id12anm_ihds2'][i])
listCastUnique[:10]
# Out:
# ['MALIK',
#  'BHAI',
#  'BHAI',
#  'BHAT',
#  'BABA',
#  'BABA',
#  'HAJAM',
#  'SOFI',
#  'LONE',
#  'BHAT']

# %%
listCastUnique2 = listCastUnique.copy()

# %%
len(set(listCastUnique2))
# Out:
# 46

# %%
len(listCastUnique)
# Out:
# 166

# %%
castList = []
castList.append(listCastUnique[0])
for i in range(1,len(listCastUnique)):
    count = 0
    for j in range(len(castList)):
        if(td.sorensen.normalized_similarity(listCastUnique[i].lower(),castList[j].lower())>0.65):
            listCastUnique[i] = castList[j]
            count += 1
    if(count == 0):
        castList.append(listCastUnique[i])

# %%
castList
# Out:
# ['MALIK',
#  'BHAI',
#  'BABA',
#  'HAJAM',
#  'SOFI',
#  'LONE',
#  'GANAI',
#  'RATHER',
#  'SHEIKH',
#  'MIR',
#  'KHAN',
#  'DAR',
#  'QURESHI',
#  'HAKEEM',
#  'GALKAR',
#  'SHAH',
#  'NAZRA',
#  'HALWAI',
#  'LANGOO',
#  'FAROOQI',
#  'GUZAR',
#  'PANDIT',
#  'WAGAY',
#  'NAVAKU',
#  'MALLA',
#  'SHERGOGERI',
#  'NADAF']

# %%
len(castList)
# Out:
# 27

# %%
listCastUnique.sort()
listCastUnique
# Out:
# ['BABA',
#  'BABA',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'BHAI',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'DAR',
#  'FAROOQI',
#  'GALKAR',
#  'GALKAR',
#  'GALKAR',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GANAI',
#  'GUZAR',
#  'GUZAR',
#  'GUZAR',
#  'HAJAM',
#  'HAJAM',
#  'HAKEEM',
#  'HALWAI',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'KHAN',
#  'LANGOO',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'LONE',
#  'MALIK',
#  'MALIK',
#  'MALIK',
#  'MALIK',
#  'MALIK',
#  'MALIK',
#  'MALIK',
#  'MALIK',
#  'MALIK',
#  'MALLA',
#  'MALLA',
#  'MALLA',
#  'MALLA',
#  'MALLA',
#  'MALLA',
#  'MALLA',
#  'MIR',
#  'MIR',
#  'MIR',
#  'MIR',
#  'MIR',
#  'MIR',
#  'MIR',
#  'NADAF',
#  'NAVAKU',
#  'NAZRA',
#  'PANDIT',
#  'PANDIT',
#  'PANDIT',
#  'PANDIT',
#  'QURESHI',
#  'RATHER',
#  'RATHER',
#  'RATHER',
#  'RATHER',
#  'SHAH',
#  'SHAH',
#  'SHAH',
#  'SHEIKH',
#  'SHEIKH',
#  'SHEIKH',
#  'SHEIKH',
#  'SHEIKH',
#  'SHEIKH',
#  'SHEIKH',
#  'SHEIKH',
#  'SHERGOGERI',
#  'SHERGOGERI',
#  'SHERGOGERI',
#  'SOFI',
#  'SOFI',
#  'SOFI',
#  'WAGAY',
#  'WAGAY',
#  'WAGAY',
#  'WAGAY',
#  'WAGAY',
#  'WAGAY']
